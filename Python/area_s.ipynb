# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

df = pd.read_csv('ing_3.csv')
df.head()

#df = df.groupby(['AREA NAME']).size()
#df.plot.bar(x='', y='', rot=1)  #rot=1 sets labels horizontal
# Out:
#    Unnamed: 0   index                DATE OCC  TIME OCC    AREA NAME  Crm Cd  \
# 0           0  997702  01/21/2015 12:00:00 AM      1415      Olympic     230
# 1           1  997703  09/01/2015 12:00:00 AM      1550      Pacific     946
# 2           2  997704  03/23/2015 12:00:00 AM       600  N Hollywood     354
# 3           3  997705  06/01/2015 12:00:00 AM       800    Hollywood     354
# 4           4  997706  12/15/2015 12:00:00 AM       945     Wilshire     354
#
#                                       Crm Cd Desc  Vict Age Vict Sex  \
# 0  ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT        28        F
# 1                       OTHER MISCELLANEOUS CRIME         0        X
# 2                               THEFT OF IDENTITY        40        M
# 3                               THEFT OF IDENTITY        50        F
# 4                               THEFT OF IDENTITY        51        M
#
#   Vict Descent                        Premis Desc  \
# ...

# %%
#area = df.groupby(['AREA NAME']).size()
#area

#area = df[["AREA NAME","Vict Sex"]] 
#area["Vict Sex"]

dd = df.groupby(['AREA NAME','Vict Sex']).count()  #지역별 성별의 수 count
dd
# Out:
#                       Unnamed: 0  index  DATE OCC  TIME OCC  Crm Cd  \
# AREA NAME   Vict Sex
# 77th Street F              32038  32038     32038     32038   32038
#             M              25754  25754     25754     25754   25754
#             X               1928   1928      1928      1928    1928
# Central     F              19841  19841     19841     19841   19841
#             M              29680  29680     29680     29680   29680
#             X               1139   1139      1139      1139    1139
# Devonshire  F              16926  16926     16926     16926   16926
#             M              19489  19489     19489     19489   19489
#             X               4708   4708      4708      4708    4708
# Foothill    F              14255  14255     14255     14255   14255
#             M              16517  16517     16517     16517   16517
#             X                 66     66        66        66      66
# ...

# %%
area_s = df.groupby(['AREA NAME','Vict Sex']).count()[['index']] #지역별 성별의 집합
area_s
# Out:
#                       index
# AREA NAME   Vict Sex
# 77th Street F         32038
#             M         25754
#             X          1928
# Central     F         19841
#             M         29680
#             X          1139
# Devonshire  F         16926
#             M         19489
#             X          4708
# Foothill    F         14255
#             M         16517
#             X            66
# Harbor      F         16469
#             M         17387
#             X          2783
# Hollenbeck  F         15676
#             M         15916
#             X          1887
# Hollywood   F         16902
#             M         23620
#             X          4898
# Mission     F         19521
#             M         21138
#             X           360
# N Hollywood F         20408
#             M         27675
#             X           863
# Newton      F         19636
#             M         22044
#             X           114
# ...                     ...
# ...

# %%
 
# Create bars
area_s.index
# Show graphic
#plt.show()
# Out:
# MultiIndex(levels=[['77th Street', 'Central', 'Devonshire', 'Foothill', 'Harbor', 'Hollenbeck', 'Hollywood', 'Mission', 'N Hollywood', 'Newton', 'Northeast', 'Olympic', 'Pacific', 'Rampart', 'Southeast', 'Southwest', 'Topanga', 'Van Nuys', 'West LA', 'West Valley', 'Wilshire'], ['F', 'M', 'X']],
#            codes=[[0, 0, 0, 1, 1, 1, 2, 2, 2, 3, 3, 3, 4, 4, 4, 5, 5, 5, 6, 6, 6, 7, 7, 7, 8, 8, 8, 9, 9, 9, 10, 10, 10, 11, 11, 11, 12, 12, 12, 13, 13, 13, 14, 14, 14, 15, 15, 15, 16, 16, 16, 17, 17, 17, 18, 18, 18, 19, 19, 19, 20, 20, 20], [0, 1, 2, 0, 1, 2, 0, 1, 2, 0, 1, 2, 0, 1, 2, 0, 1, 2, 0, 1, 2, 0, 1, 2, 0, 1, 2, 0, 1, 2, 0, 1, 2, 0, 1, 2, 0, 1, 2, 0, 1, 2, 0, 1, 2, 0, 1, 2, 0, 1, 2, 0, 1, 2, 0, 1, 2, 0, 1, 2, 0, 1, 2]],
#            names=['AREA NAME', 'Vict Sex'])

# %% [markdown]
# ## 바 그래프 간격 조절

# %%
area_s.unstack(level=1).plot(kind='bar', subplots=False,figsize=(10,6),width=2) #성별별 지역
#plt.legend()

plt.show()

# %%
plt.pie(sizes, explode=explode, labels=labels, colors=colors,
autopct='%1.1f%%', shadow=True, startangle=140)
